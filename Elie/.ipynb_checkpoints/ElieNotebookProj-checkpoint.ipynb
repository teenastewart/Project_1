# %%
# Dependencies

import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
import csv
import json
import numpy as np
import datetime
from datetime import date

# %%
#Getting weather data for 2018, 2019, 2020
url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx"
request = url + "?" + "key=" + api_key +"&q=Minneapolis,MN" + "&date=2018-01-01" + "&enddate=2020-12-31" + "&tp=24" + "&format=json"
response = requests.get(request)
weather_data = response.json()

print(json.dumps(weather_data, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "request": [
#             {
#                 "query": "Minneapolis, United States of America",
#                 "type": "City"
#             }
#         ],
#         "weather": [
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "97",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "05:42 PM",
#                         "moonset": "08:06 AM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:43 PM"
#                     }
#                 ],
#                 "avgtempC": "-22",
#                 "avgtempF": "-7",
#                 "date": "2018-01-01",
#                 "hourly": [
#                     {
#                         "DewPointC": "-23",
#                         "DewPointF": "-10",
#                         "FeelsLikeC": "-30",
#                         "FeelsLikeF": "-22",
#                         "HeatIndexC": "-22",
#                         "HeatIndexF": "-8",
#                         "WindChillC": "-30",
#                         "WindChillF": "-22",
#                         "WindGustKmph": "15",
#                         "WindGustMiles": "9",
#                         "cloudcover": "42",
#                         "humidity": "91",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1046",
#                         "pressureInches": "31",
#                         "tempC": "-18",
#                         "tempF": "-0",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "9",
#                         "visibilityMiles": "5",
#                         "weatherCode": "143",
#                         "weatherDesc": [
#                             {
#                                 "value": "Mist"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0006_mist.png"
#                             }
#                         ],
#                         "winddir16Point": "WNW",
#                         "winddirDegree": "286",
#                         "windspeedKmph": "10",
#                         "windspeedMiles": "6"
#                     }
#                 ],
#                 "maxtempC": "-18",
#                 "maxtempF": "-0",
#                 "mintempC": "-25",
#                 "mintempF": "-12",
#                 "sunHour": "6.9",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "100",
#                         "moon_phase": "Full Moon",
#                         "moonrise": "06:49 PM",
#                         "moonset": "09:09 AM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:44 PM"
#                     }
#                 ],
#                 "avgtempC": "-16",
#                 "avgtempF": "4",
#                 "date": "2018-01-02",
#                 "hourly": [
#                     {
#                         "DewPointC": "-18",
#                         "DewPointF": "-1",
#                         "FeelsLikeC": "-25",
#                         "FeelsLikeF": "-14",
#                         "HeatIndexC": "-17",
#                         "HeatIndexF": "2",
#                         "WindChillC": "-25",
#                         "WindChillF": "-14",
#                         "WindGustKmph": "25",
#                         "WindGustMiles": "16",
#                         "cloudcover": "55",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1029",
#                         "pressureInches": "31",
#                         "tempC": "-10",
#                         "tempF": "13",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "122",
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "winddir16Point": "WSW",
#                         "winddirDegree": "244",
#                         "windspeedKmph": "16",
#                         "windspeedMiles": "10"
#                     }
#                 ],
#                 "maxtempC": "-10",
#                 "maxtempF": "13",
#                 "mintempC": "-21",
#                 "mintempF": "-6",
#                 "sunHour": "5.1",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "89",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "08:01 PM",
#                         "moonset": "10:03 AM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:44 PM"
#                     }
#                 ],
#                 "avgtempC": "-17",
#                 "avgtempF": "1",
#                 "date": "2018-01-03",
#                 "hourly": [
#                     {
#                         "DewPointC": "-19",
#                         "DewPointF": "-2",
#                         "FeelsLikeC": "-26",
#                         "FeelsLikeF": "-14",
#                         "HeatIndexC": "-17",
#                         "HeatIndexF": "1",
#                         "WindChillC": "-26",
#                         "WindChillF": "-14",
#                         "WindGustKmph": "20",
#                         "WindGustMiles": "12",
#                         "cloudcover": "88",
#                         "humidity": "88",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1028",
#                         "pressureInches": "31",
#                         "tempC": "-16",
#                         "tempF": "3",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "326",
#                         "weatherDesc": [
#                             {
#                                 "value": "Light snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0011_light_snow_showers.png"
#                             }
#                         ],
#                         "winddir16Point": "NW",
#                         "winddirDegree": "321",
#                         "windspeedKmph": "13",
#                         "windspeedMiles": "8"
#                     }
#                 ],
#                 "maxtempC": "-16",
#                 "maxtempF": "3",
#                 "mintempC": "-19",
#                 "mintempF": "-2",
#                 "sunHour": "3.3",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "81",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "09:15 PM",
#                         "moonset": "10:49 AM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:45 PM"
#                     }
#                 ],
#                 "avgtempC": "-18",
#                 "avgtempF": "-1",
#                 "date": "2018-01-04",
#                 "hourly": [
#                     {
#                         "DewPointC": "-20",
#                         "DewPointF": "-4",
#                         "FeelsLikeC": "-22",
#                         "FeelsLikeF": "-8",
#                         "HeatIndexC": "-19",
#                         "HeatIndexF": "-2",
#                         "WindChillC": "-22",
#                         "WindChillF": "-8",
#                         "WindGustKmph": "7",
#                         "WindGustMiles": "4",
#                         "cloudcover": "51",
#                         "humidity": "88",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1033",
#                         "pressureInches": "31",
#                         "tempC": "-16",
#                         "tempF": "4",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "122",
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "winddir16Point": "ENE",
#                         "winddirDegree": "62",
#                         "windspeedKmph": "5",
#                         "windspeedMiles": "3"
#                     }
#                 ],
#                 "maxtempC": "-16",
#                 "maxtempF": "4",
#                 "mintempC": "-21",
#                 "mintempF": "-5",
#                 "sunHour": "5.1",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "74",
#                         "moon_phase": "Waning Gibbous",
#                         "moonrise": "10:27 PM",
#                         "moonset": "11:28 AM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:46 PM"
#                     }
#                 ],
#                 "avgtempC": "-18",
#                 "avgtempF": "-1",
#                 "date": "2018-01-05",
#                 "hourly": [
#                     {
#                         "DewPointC": "-21",
#                         "DewPointF": "-5",
#                         "FeelsLikeC": "-24",
#                         "FeelsLikeF": "-11",
#                         "HeatIndexC": "-19",
#                         "HeatIndexF": "-2",
#                         "WindChillC": "-24",
#                         "WindChillF": "-11",
#                         "WindGustKmph": "9",
#                         "WindGustMiles": "6",
#                         "cloudcover": "8",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1038",
#                         "pressureInches": "31",
#                         "tempC": "-16",
#                         "tempF": "4",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "113",
#                         "weatherDesc": [
#                             {
#                                 "value": "Sunny"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png"
#                             }
#                         ],
#                         "winddir16Point": "S",
#                         "winddirDegree": "185",
#                         "windspeedKmph": "6",
#                         "windspeedMiles": "4"
#                     }
#                 ],
#                 "maxtempC": "-16",
#                 "maxtempF": "4",
#                 "mintempC": "-22",
#                 "mintempF": "-7",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "67",
#                         "moon_phase": "Waning Gibbous",
#                         "moonrise": "11:38 PM",
#                         "moonset": "12:00 PM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:48 PM"
#                     }
#                 ],
#                 "avgtempC": "-17",
#                 "avgtempF": "1",
#                 "date": "2018-01-06",
#                 "hourly": [
#                     {
#                         "DewPointC": "-20",
#                         "DewPointF": "-3",
#                         "FeelsLikeC": "-24",
#                         "FeelsLikeF": "-10",
#                         "HeatIndexC": "-17",
#                         "HeatIndexF": "1",
#                         "WindChillC": "-24",
#                         "WindChillF": "-10",
#                         "WindGustKmph": "17",
#                         "WindGustMiles": "10",
#                         "cloudcover": "33",
#                         "humidity": "83",
#                         "precipInches": "0.0",
#                         "precipMM": "0.1",
#                         "pressure": "1034",
#                         "pressureInches": "31",
#                         "tempC": "-14",
#                         "tempF": "7",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "9",
#                         "visibilityMiles": "5",
#                         "weatherCode": "122",
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "winddir16Point": "SE",
#                         "winddirDegree": "141",
#                         "windspeedKmph": "12",
#                         "windspeedMiles": "7"
#                     }
#                 ],
#                 "maxtempC": "-14",
#                 "maxtempF": "7",
#                 "mintempC": "-21",
#                 "mintempF": "-5",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.1",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "59",
#                         "moon_phase": "Waning Gibbous",
#                         "moonrise": "No moonrise",
#                         "moonset": "12:30 PM",
#                         "sunrise": "08:51 AM",
#                         "sunset": "05:49 PM"
#                     }
#                 ],
#                 "avgtempC": "-6",
#                 "avgtempF": "21",
#                 "date": "2018-01-07",
#                 "hourly": [
#                     {
#                         "DewPointC": "-9",
#                         "DewPointF": "16",
#                         "FeelsLikeC": "-13",
#                         "FeelsLikeF": "8",
#                         "HeatIndexC": "-7",
#                         "HeatIndexF": "19",
#                         "WindChillC": "-13",
#                         "WindChillF": "8",
#                         "WindGustKmph": "21",
#                         "WindGustMiles": "13",
#                         "cloudcover": "68",
#                         "humidity": "89",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1014",
#                         "pressureInches": "30",
#                         "tempC": "-3",
#                         "tempF": "26",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "326",
#                         "weatherDesc": [
#                             {
#                                 "value": "Light snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0011_light_snow_showers.png"
#                             }
#                         ],
#                         "winddir16Point": "SW",
#                         "winddirDegree": "217",
#                         "windspeedKmph": "14",
#                         "windspeedMiles": "8"
#                     }
#                 ],
#                 "maxtempC": "-3",
#                 "maxtempF": "26",
#                 "mintempC": "-11",
#                 "mintempF": "12",
#                 "sunHour": "5.1",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "52",
#                         "moon_phase": "Last Quarter",
#                         "moonrise": "12:44 AM",
#                         "moonset": "12:58 PM",
#                         "sunrise": "08:50 AM",
#                         "sunset": "05:50 PM"
#                     }
#                 ],
#                 "avgtempC": "-3",
#                 "avgtempF": "26",
#                 "date": "2018-01-08",
#                 "hourly": [
#                     {
#                         "DewPointC": "-6",
#                         "DewPointF": "22",
#                         "FeelsLikeC": "-8",
#                         "FeelsLikeF": "18",
#                         "HeatIndexC": "-4",
#                         "HeatIndexF": "25",
#                         "WindChillC": "-8",
#                         "WindChillF": "18",
#                         "WindGustKmph": "17",
#                         "WindGustMiles": "11",
#                         "cloudcover": "23",
#                         "humidity": "89",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1017",
#                         "pressureInches": "31",
#                         "tempC": "-0",
#                         "tempF": "32",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "9",
#                         "visibilityMiles": "5",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "W",
#                         "winddirDegree": "278",
#                         "windspeedKmph": "9",
#                         "windspeedMiles": "6"
#                     }
#                 ],
#                 "maxtempC": "-0",
#                 "maxtempF": "32",
#                 "mintempC": "-7",
#                 "mintempF": "20",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "45",
#                         "moon_phase": "Last Quarter",
#                         "moonrise": "01:49 AM",
#                         "moonset": "01:25 PM",
#                         "sunrise": "08:50 AM",
#                         "sunset": "05:51 PM"
#                     }
#                 ],
#                 "avgtempC": "0",
#                 "avgtempF": "32",
#                 "date": "2018-01-09",
#                 "hourly": [
#                     {
#                         "DewPointC": "-3",
#                         "DewPointF": "27",
#                         "FeelsLikeC": "-5",
#                         "FeelsLikeF": "23",
#                         "HeatIndexC": "-1",
#                         "HeatIndexF": "31",
#                         "WindChillC": "-5",
#                         "WindChillF": "23",
#                         "WindGustKmph": "24",
#                         "WindGustMiles": "15",
#                         "cloudcover": "34",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1017",
#                         "pressureInches": "31",
#                         "tempC": "2",
#                         "tempF": "36",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "SE",
#                         "winddirDegree": "135",
#                         "windspeedKmph": "14",
#                         "windspeedMiles": "9"
#                     }
#                 ],
#                 "maxtempC": "2",
#                 "maxtempF": "36",
#                 "mintempC": "-3",
#                 "mintempF": "26",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "38",
#                         "moon_phase": "Last Quarter",
#                         "moonrise": "02:52 AM",
#                         "moonset": "01:53 PM",
#                         "sunrise": "08:50 AM",
#                         "sunset": "05:52 PM"
#                     }
#                 ],
#                 "avgtempC": "2",
#                 "avgtempF": "35",
#                 "date": "2018-01-10",
#                 "hourly": [
#                     {
#                         "DewPointC": "0",
#                         "DewPointF": "32",
#                         "FeelsLikeC": "-3",
#                         "FeelsLikeF": "26",
#                         "HeatIndexC": "1",
#                         "HeatIndexF": "34",
#                         "WindChillC": "-3",
#                         "WindChillF": "26",
#                         "WindGustKmph": "25",
#                         "WindGustMiles": "16",
#                         "cloudcover": "87",
#                         "humidity": "93",
#                         "precipInches": "0.0",
#                         "precipMM": "0.2",
#                         "pressure": "1003",
#                         "pressureInches": "30",
#                         "tempC": "2",
#                         "tempF": "36",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "7",
#                         "visibilityMiles": "4",
#                         "weatherCode": "143",
#                         "weatherDesc": [
#                             {
#                                 "value": "Mist"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0006_mist.png"
#                             }
#                         ],
#                         "winddir16Point": "S",
#                         "winddirDegree": "175",
#                         "windspeedKmph": "16",
#                         "windspeedMiles": "10"
#                     }
#                 ],
#                 "maxtempC": "2",
#                 "maxtempF": "36",
#                 "mintempC": "-1",
#                 "mintempF": "31",
#                 "sunHour": "3.4",
#                 "totalSnow_cm": "0.1",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "30",
#                         "moon_phase": "Last Quarter",
#                         "moonrise": "03:53 AM",
#                         "moonset": "02:23 PM",
#                         "sunrise": "08:49 AM",
#                         "sunset": "05:53 PM"
#                     }
#                 ],
#                 "avgtempC": "-13",
#                 "avgtempF": "9",
#                 "date": "2018-01-11",
#                 "hourly": [
#                     {
#                         "DewPointC": "-12",
#                         "DewPointF": "11",
#                         "FeelsLikeC": "-19",
#                         "FeelsLikeF": "-2",
#                         "HeatIndexC": "-10",
#                         "HeatIndexF": "14",
#                         "WindChillC": "-19",
#                         "WindChillF": "-2",
#                         "WindGustKmph": "28",
#                         "WindGustMiles": "17",
#                         "cloudcover": "100",
#                         "humidity": "89",
#                         "precipInches": "0.2",
#                         "precipMM": "4.9",
#                         "pressure": "1015",
#                         "pressureInches": "30",
#                         "tempC": "-10",
#                         "tempF": "15",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "5",
#                         "visibilityMiles": "2",
#                         "weatherCode": "338",
#                         "weatherDesc": [
#                             {
#                                 "value": "Heavy snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png"
#                             }
#                         ],
#                         "winddir16Point": "WNW",
#                         "winddirDegree": "303",
#                         "windspeedKmph": "21",
#                         "windspeedMiles": "13"
#                     }
#                 ],
#                 "maxtempC": "-10",
#                 "maxtempF": "15",
#                 "mintempC": "-16",
#                 "mintempF": "3",
#                 "sunHour": "3.4",
#                 "totalSnow_cm": "4.2",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "23",
#                         "moon_phase": "Waning Crescent",
#                         "moonrise": "04:52 AM",
#                         "moonset": "02:56 PM",
#                         "sunrise": "08:49 AM",
#                         "sunset": "05:54 PM"
#                     }
#                 ],
#                 "avgtempC": "-20",
#                 "avgtempF": "-4",
#                 "date": "2018-01-12",
#                 "hourly": [
#                     {
#                         "DewPointC": "-21",
#                         "DewPointF": "-6",
#                         "FeelsLikeC": "-28",
#                         "FeelsLikeF": "-19",
#                         "HeatIndexC": "-20",
#                         "HeatIndexF": "-3",
#                         "WindChillC": "-28",
#                         "WindChillF": "-19",
#                         "WindGustKmph": "17",
#                         "WindGustMiles": "11",
#                         "cloudcover": "28",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1037",
#                         "pressureInches": "31",
#                         "tempC": "-17",
#                         "tempF": "2",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "NNW",
#                         "winddirDegree": "332",
#                         "windspeedKmph": "12",
#                         "windspeedMiles": "8"
#                     }
#                 ],
#                 "maxtempC": "-17",
#                 "maxtempF": "2",
#                 "mintempC": "-23",
#                 "mintempF": "-9",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "16",
#                         "moon_phase": "Waning Crescent",
#                         "moonrise": "05:50 AM",
#                         "moonset": "03:33 PM",
#                         "sunrise": "08:49 AM",
#                         "sunset": "05:55 PM"
#                     }
#                 ],
#                 "avgtempC": "-18",
#                 "avgtempF": "-1",
#                 "date": "2018-01-13",
#                 "hourly": [
#                     {
#                         "DewPointC": "-21",
#                         "DewPointF": "-6",
#                         "FeelsLikeC": "-25",
#                         "FeelsLikeF": "-12",
#                         "HeatIndexC": "-19",
#                         "HeatIndexF": "-2",
#                         "WindChillC": "-25",
#                         "WindChillF": "-12",
#                         "WindGustKmph": "9",
#                         "WindGustMiles": "6",
#                         "cloudcover": "6",
#                         "humidity": "85",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1043",
#                         "pressureInches": "31",
#                         "tempC": "-15",
#                         "tempF": "6",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "113",
#                         "weatherDesc": [
#                             {
#                                 "value": "Sunny"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png"
#                             }
#                         ],
#                         "winddir16Point": "W",
#                         "winddirDegree": "275",
#                         "windspeedKmph": "7",
#                         "windspeedMiles": "4"
#                     }
#                 ],
#                 "maxtempC": "-15",
#                 "maxtempF": "6",
#                 "mintempC": "-23",
#                 "mintempF": "-9",
#                 "sunHour": "8.7",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "9",
#                         "moon_phase": "Waning Crescent",
#                         "moonrise": "06:44 AM",
#                         "moonset": "04:14 PM",
#                         "sunrise": "08:48 AM",
#                         "sunset": "05:57 PM"
#                     }
#                 ],
#                 "avgtempC": "-14",
#                 "avgtempF": "7",
#                 "date": "2018-01-14",
#                 "hourly": [
#                     {
#                         "DewPointC": "-16",
#                         "DewPointF": "3",
#                         "FeelsLikeC": "-22",
#                         "FeelsLikeF": "-8",
#                         "HeatIndexC": "-15",
#                         "HeatIndexF": "5",
#                         "WindChillC": "-22",
#                         "WindChillF": "-8",
#                         "WindGustKmph": "19",
#                         "WindGustMiles": "12",
#                         "cloudcover": "71",
#                         "humidity": "89",
#                         "precipInches": "0.1",
#                         "precipMM": "1.8",
#                         "pressure": "1030",
#                         "pressureInches": "31",
#                         "tempC": "-10",
#                         "tempF": "15",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "8",
#                         "visibilityMiles": "4",
#                         "weatherCode": "338",
#                         "weatherDesc": [
#                             {
#                                 "value": "Heavy snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png"
#                             }
#                         ],
#                         "winddir16Point": "SSW",
#                         "winddirDegree": "192",
#                         "windspeedKmph": "13",
#                         "windspeedMiles": "8"
#                     }
#                 ],
#                 "maxtempC": "-10",
#                 "maxtempF": "15",
#                 "mintempC": "-21",
#                 "mintempF": "-5",
#                 "sunHour": "3.4",
#                 "totalSnow_cm": "1.5",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "1",
#                         "moon_phase": "Waning Crescent",
#                         "moonrise": "07:35 AM",
#                         "moonset": "05:01 PM",
#                         "sunrise": "08:47 AM",
#                         "sunset": "05:58 PM"
#                     }
#                 ],
#                 "avgtempC": "-17",
#                 "avgtempF": "1",
#                 "date": "2018-01-15",
#                 "hourly": [
#                     {
#                         "DewPointC": "-18",
#                         "DewPointF": "-0",
#                         "FeelsLikeC": "-26",
#                         "FeelsLikeF": "-16",
#                         "HeatIndexC": "-16",
#                         "HeatIndexF": "2",
#                         "WindChillC": "-26",
#                         "WindChillF": "-16",
#                         "WindGustKmph": "29",
#                         "WindGustMiles": "18",
#                         "cloudcover": "100",
#                         "humidity": "89",
#                         "precipInches": "0.0",
#                         "precipMM": "1.2",
#                         "pressure": "1033",
#                         "pressureInches": "31",
#                         "tempC": "-16",
#                         "tempF": "3",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "5",
#                         "visibilityMiles": "2",
#                         "weatherCode": "332",
#                         "weatherDesc": [
#                             {
#                                 "value": "Moderate snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png"
#                             }
#                         ],
#                         "winddir16Point": "NNW",
#                         "winddirDegree": "326",
#                         "windspeedKmph": "20",
#                         "windspeedMiles": "12"
#                     }
#                 ],
#                 "maxtempC": "-16",
#                 "maxtempF": "3",
#                 "mintempC": "-18",
#                 "mintempF": "-1",
#                 "sunHour": "3.4",
#                 "totalSnow_cm": "1.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "0",
#                         "moon_phase": "New Moon",
#                         "moonrise": "08:21 AM",
#                         "moonset": "05:52 PM",
#                         "sunrise": "08:47 AM",
#                         "sunset": "05:59 PM"
#                     }
#                 ],
#                 "avgtempC": "-17",
#                 "avgtempF": "1",
#                 "date": "2018-01-16",
#                 "hourly": [
#                     {
#                         "DewPointC": "-18",
#                         "DewPointF": "-1",
#                         "FeelsLikeC": "-25",
#                         "FeelsLikeF": "-13",
#                         "HeatIndexC": "-18",
#                         "HeatIndexF": "1",
#                         "WindChillC": "-25",
#                         "WindChillF": "-13",
#                         "WindGustKmph": "17",
#                         "WindGustMiles": "10",
#                         "cloudcover": "82",
#                         "humidity": "94",
#                         "precipInches": "0.0",
#                         "precipMM": "0.1",
#                         "pressure": "1041",
#                         "pressureInches": "31",
#                         "tempC": "-14",
#                         "tempF": "6",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "8",
#                         "visibilityMiles": "4",
#                         "weatherCode": "326",
#                         "weatherDesc": [
#                             {
#                                 "value": "Light snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0011_light_snow_showers.png"
#                             }
#                         ],
#                         "winddir16Point": "WNW",
#                         "winddirDegree": "292",
#                         "windspeedKmph": "11",
#                         "windspeedMiles": "7"
#                     }
#                 ],
#                 "maxtempC": "-14",
#                 "maxtempF": "6",
#                 "mintempC": "-20",
#                 "mintempF": "-3",
#                 "sunHour": "3.4",
#                 "totalSnow_cm": "0.1",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "0",
#                         "moon_phase": "New Moon",
#                         "moonrise": "09:03 AM",
#                         "moonset": "06:47 PM",
#                         "sunrise": "08:46 AM",
#                         "sunset": "06:00 PM"
#                     }
#                 ],
#                 "avgtempC": "-10",
#                 "avgtempF": "14",
#                 "date": "2018-01-17",
#                 "hourly": [
#                     {
#                         "DewPointC": "-14",
#                         "DewPointF": "8",
#                         "FeelsLikeC": "-19",
#                         "FeelsLikeF": "-2",
#                         "HeatIndexC": "-11",
#                         "HeatIndexF": "12",
#                         "WindChillC": "-19",
#                         "WindChillF": "-2",
#                         "WindGustKmph": "26",
#                         "WindGustMiles": "16",
#                         "cloudcover": "14",
#                         "humidity": "83",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1028",
#                         "pressureInches": "31",
#                         "tempC": "-5",
#                         "tempF": "22",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "SW",
#                         "winddirDegree": "223",
#                         "windspeedKmph": "16",
#                         "windspeedMiles": "10"
#                     }
#                 ],
#                 "maxtempC": "-5",
#                 "maxtempF": "22",
#                 "mintempC": "-18",
#                 "mintempF": "-1",
#                 "sunHour": "9.5",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "6",
#                         "moon_phase": "Waxing Crescent",
#                         "moonrise": "09:40 AM",
#                         "moonset": "07:46 PM",
#                         "sunrise": "08:46 AM",
#                         "sunset": "06:02 PM"
#                     }
#                 ],
#                 "avgtempC": "-2",
#                 "avgtempF": "29",
#                 "date": "2018-01-18",
#                 "hourly": [
#                     {
#                         "DewPointC": "-5",
#                         "DewPointF": "22",
#                         "FeelsLikeC": "-8",
#                         "FeelsLikeF": "18",
#                         "HeatIndexC": "-3",
#                         "HeatIndexF": "26",
#                         "WindChillC": "-8",
#                         "WindChillF": "18",
#                         "WindGustKmph": "23",
#                         "WindGustMiles": "14",
#                         "cloudcover": "10",
#                         "humidity": "84",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1014",
#                         "pressureInches": "30",
#                         "tempC": "1",
#                         "tempF": "35",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "SW",
#                         "winddirDegree": "230",
#                         "windspeedKmph": "12",
#                         "windspeedMiles": "8"
#                     }
#                 ],
#                 "maxtempC": "1",
#                 "maxtempF": "35",
#                 "mintempC": "-6",
#                 "mintempF": "20",
#                 "sunHour": "9.6",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "13",
#                         "moon_phase": "Waxing Crescent",
#                         "moonrise": "10:13 AM",
#                         "moonset": "08:46 PM",
#                         "sunrise": "08:45 AM",
#                         "sunset": "06:03 PM"
#                     }
#                 ],
#                 "avgtempC": "1",
#                 "avgtempF": "33",
#                 "date": "2018-01-19",
#                 "hourly": [
#                     {
#                         "DewPointC": "-2",
#                         "DewPointF": "28",
#                         "FeelsLikeC": "-4",
#                         "FeelsLikeF": "25",
#                         "HeatIndexC": "-0",
#                         "HeatIndexF": "32",
#                         "WindChillC": "-4",
#                         "WindChillF": "25",
#                         "WindGustKmph": "21",
#                         "WindGustMiles": "13",
#                         "cloudcover": "21",
#                         "humidity": "86",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1004",
#                         "pressureInches": "30",
#                         "tempC": "2",
#                         "tempF": "36",
#                         "time": "24",
#                         "uvIndex": "2",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "116",
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "SW",
#                         "winddirDegree": "221",
#                         "windspeedKmph": "11",
#                         "windspeedMiles": "7"
#                     }
#                 ],
#                 "maxtempC": "2",
#                 "maxtempF": "36",
#                 "mintempC": "-3",
#                 "mintempF": "28",
#                 "sunHour": "9.6",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "20",
#                         "moon_phase": "Waxing Crescent",
#                         "moonrise": "10:43 AM",
#                         "moonset": "09:49 PM",
#                         "sunrise": "08:44 AM",
# ...
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png"
#                             }
#                         ],
#                         "winddir16Point": "NW",
#                         "winddirDegree": "316",
#                         "windspeedKmph": "6",
#                         "windspeedMiles": "4"
#                     }
#                 ],
#                 "maxtempC": "-10",
#                 "maxtempF": "15",
#                 "mintempC": "-15",
#                 "mintempF": "5",
#                 "sunHour": "9.8",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "2"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "93",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "05:33 PM",
#                         "moonset": "07:47 AM",
#                         "sunrise": "08:35 AM",
#                         "sunset": "06:18 PM"
#                     }
#                 ],
#                 "avgtempC": "-10",
#                 "avgtempF": "14",
#                 "date": "2018-01-30",
#                 "hourly": [
#                     {
#                         "DewPointC": "-13",
#                         "DewPointF": "9",
#                         "FeelsLikeC": "-17",
#                         "FeelsLikeF": "2",
#                         "HeatIndexC": "-10",
#                         "HeatIndexF": "14",
#                         "WindChillC": "-17",
#                         "WindChillF": "2",
#                         "WindGustKmph": "23",
#                         "WindGustMiles": "14",
#                         "cloudcover": "46",
#                         "humidity": "82",
#                         "precipInches": "0.0",
#                         "precipMM": "0.1",
#                         "pressure": "1023",
#                         "pressureInches": "31",
#                         "tempC": "-5",
#                         "tempF": "23",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "9",
#                         "visibilityMiles": "5",
#                         "weatherCode": "323",
#                         "weatherDesc": [
#                             {
#                                 "value": "Patchy light snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0011_light_snow_showers.png"
#                             }
#                         ],
#                         "winddir16Point": "SSE",
#                         "winddirDegree": "162",
#                         "windspeedKmph": "15",
#                         "windspeedMiles": "9"
#                     }
#                 ],
#                 "maxtempC": "-5",
#                 "maxtempF": "23",
#                 "mintempC": "-16",
#                 "mintempF": "4",
#                 "sunHour": "8.3",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "97",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "06:46 PM",
#                         "moonset": "08:37 AM",
#                         "sunrise": "08:34 AM",
#                         "sunset": "06:19 PM"
#                     }
#                 ],
#                 "avgtempC": "-4",
#                 "avgtempF": "25",
#                 "date": "2018-01-31",
#                 "hourly": [
#                     {
#                         "DewPointC": "-6",
#                         "DewPointF": "21",
#                         "FeelsLikeC": "-10",
#                         "FeelsLikeF": "15",
#                         "HeatIndexC": "-4",
#                         "HeatIndexF": "25",
#                         "WindChillC": "-10",
#                         "WindChillF": "15",
#                         "WindGustKmph": "21",
#                         "WindGustMiles": "13",
#                         "cloudcover": "58",
#                         "humidity": "86",
#                         "precipInches": "0.1",
#                         "precipMM": "3.1",
#                         "pressure": "1008",
#                         "pressureInches": "30",
#                         "tempC": "-3",
#                         "tempF": "27",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "7",
#                         "visibilityMiles": "4",
#                         "weatherCode": "335",
#                         "weatherDesc": [
#                             {
#                                 "value": "Patchy heavy snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0012_heavy_snow_showers.png"
#                             }
#                         ],
#                         "winddir16Point": "W",
#                         "winddirDegree": "275",
#                         "windspeedKmph": "14",
#                         "windspeedMiles": "9"
#                     }
#                 ],
#                 "maxtempC": "-3",
#                 "maxtempF": "27",
#                 "mintempC": "-9",
#                 "mintempF": "16",
#                 "sunHour": "9.9",
#                 "totalSnow_cm": "2.3",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "88",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "08:01 PM",
#                         "moonset": "09:20 AM",
#                         "sunrise": "08:32 AM",
#                         "sunset": "06:21 PM"
#                     }
#                 ],
#                 "avgtempC": "-18",
#                 "avgtempF": "0",
#                 "date": "2018-02-01",
#                 "hourly": [
#                     {
#                         "DewPointC": "-20",
#                         "DewPointF": "-4",
#                         "FeelsLikeC": "-27",
#                         "FeelsLikeF": "-16",
#                         "HeatIndexC": "-17",
#                         "HeatIndexF": "1",
#                         "WindChillC": "-27",
#                         "WindChillF": "-16",
#                         "WindGustKmph": "25",
#                         "WindGustMiles": "15",
#                         "cloudcover": "54",
#                         "humidity": "79",
#                         "precipInches": "0.0",
#                         "precipMM": "0.1",
#                         "pressure": "1029",
#                         "pressureInches": "31",
#                         "tempC": "-16",
#                         "tempF": "4",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "5",
#                         "weatherCode": "122",
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "winddir16Point": "NW",
#                         "winddirDegree": "311",
#                         "windspeedKmph": "17",
#                         "windspeedMiles": "11"
#                     }
#                 ],
#                 "maxtempC": "-16",
#                 "maxtempF": "4",
#                 "mintempC": "-19",
#                 "mintempF": "-3",
#                 "sunHour": "8.3",
#                 "totalSnow_cm": "0.1",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "81",
#                         "moon_phase": "Waxing Gibbous",
#                         "moonrise": "09:15 PM",
#                         "moonset": "09:56 AM",
#                         "sunrise": "08:31 AM",
#                         "sunset": "06:22 PM"
#                     }
#                 ],
#                 "avgtempC": "-17",
#                 "avgtempF": "2",
#                 "date": "2018-02-02",
#                 "hourly": [
#                     {
#                         "DewPointC": "-19",
#                         "DewPointF": "-2",
#                         "FeelsLikeC": "-23",
#                         "FeelsLikeF": "-9",
#                         "HeatIndexC": "-17",
#                         "HeatIndexF": "1",
#                         "WindChillC": "-23",
#                         "WindChillF": "-9",
#                         "WindGustKmph": "10",
#                         "WindGustMiles": "6",
#                         "cloudcover": "41",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.0",
#                         "pressure": "1033",
#                         "pressureInches": "31",
#                         "tempC": "-14",
#                         "tempF": "8",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "weatherCode": "119",
#                         "weatherDesc": [
#                             {
#                                 "value": "Cloudy"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png"
#                             }
#                         ],
#                         "winddir16Point": "SSW",
#                         "winddirDegree": "209",
#                         "windspeedKmph": "7",
#                         "windspeedMiles": "4"
#                     }
#                 ],
#                 "maxtempC": "-14",
#                 "maxtempF": "8",
#                 "mintempC": "-21",
#                 "mintempF": "-6",
#                 "sunHour": "9.9",
#                 "totalSnow_cm": "0.0",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "73",
#                         "moon_phase": "Waning Gibbous",
#                         "moonrise": "10:25 PM",
#                         "moonset": "10:28 AM",
#                         "sunrise": "08:30 AM",
#                         "sunset": "06:24 PM"
#                     }
#                 ],
#                 "avgtempC": "-10",
#                 "avgtempF": "14",
#                 "date": "2018-02-03",
#                 "hourly": [
#                     {
#                         "DewPointC": "-12",
#                         "DewPointF": "10",
#                         "FeelsLikeC": "-17",
#                         "FeelsLikeF": "2",
#                         "HeatIndexC": "-11",
#                         "HeatIndexF": "12",
#                         "WindChillC": "-17",
#                         "WindChillF": "2",
#                         "WindGustKmph": "18",
#                         "WindGustMiles": "11",
#                         "cloudcover": "89",
#                         "humidity": "93",
#                         "precipInches": "0.1",
#                         "precipMM": "3.2",
#                         "pressure": "1016",
#                         "pressureInches": "30",
#                         "tempC": "-8",
#                         "tempF": "17",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "5",
#                         "visibilityMiles": "3",
#                         "weatherCode": "338",
#                         "weatherDesc": [
#                             {
#                                 "value": "Heavy snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png"
#                             }
#                         ],
#                         "winddir16Point": "NE",
#                         "winddirDegree": "54",
#                         "windspeedKmph": "12",
#                         "windspeedMiles": "7"
#                     }
#                 ],
#                 "maxtempC": "-8",
#                 "maxtempF": "17",
#                 "mintempC": "-13",
#                 "mintempF": "8",
#                 "sunHour": "5.0",
#                 "totalSnow_cm": "2.7",
#                 "uvIndex": "1"
#             },
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "66",
#                         "moon_phase": "Waning Gibbous",
#                         "moonrise": "11:34 PM",
#                         "moonset": "10:58 AM",
#                         "sunrise": "08:29 AM",
#                         "sunset": "06:25 PM"
#                     }
#                 ],
#                 "avgtempC": "-19",
#                 "avgtempF": "-2",
#                 "date": "2018-02-04",
#                 "hourly": [
#                     {
#                         "DewPointC": "-20",
#                         "DewPointF": "-4",
#                         "FeelsLikeC": "-27",
#                         "FeelsLikeF": "-17",
#                         "HeatIndexC": "-18",
#                         "HeatIndexF": "-1",
#                         "WindChillC": "-27",
#                         "WindChillF": "-17",
#                         "WindGustKmph": "21",
#                         "WindGustMiles": "13",
#                         "cloudcover": "53",
#                         "humidity": "87",
#                         "precipInches": "0.0",
#                         "precipMM": "0.4",
#                         "pressure": "1028",
#                         "pressureInches": "31",
#                         "tempC": "-17",
#                         "tempF": "1",
#                         "time": "24",
#                         "uvIndex": "1",
#                         "visibility": "8",
#                         "visibilityMiles": "5",
#                         "weatherCode": "329",
#                         "weatherDesc": [
#                             {
#                                 "value": "Patchy moderate snow"
#                             }
#                         ],
#                         "weatherIconUrl": [
#                             {
#                                 "value": "http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png"
#                             }
#                         ],
#                         "winddir16Point": "W",
#                         "winddirDegree": "260",
#                         "windspeedKmph": "15",
#                         "windspeedMiles": "9"
#                     }
#                 ],
#                 "maxtempC": "-17",
#                 "maxtempF": "1",
#                 "mintempC": "-21",
#                 "mintempF": "-6",
#                 "sunHour": "9.9",
#                 "totalSnow_cm": "0.3",
#                 "uvIndex": "1"
#             }
#         ]
#     }
# }

# %%
weather_df = pd.read_csv('../Resources/weather_data_long.csv')
crime_df =pd.read_csv('../Resources/NEIGHBORHOOD_CRIME_STATS.csv')
weather_2017 = weather_df[(weather_df['date'] >= '2017-01-01')]
weather_2017.to_csv("../Resources/weather_2017.csv", encoding="utf-8", index=False)

# %%
weather_df['date'] = pd.to_datetime(weather_df['date'])
weathert7_t21 = weather_df[(weather_df['date'] >= '2017-08-31') & (weather_df['date'] <= '2021-03-31')]
new_weather
# Out:
#       loc_id       date  maxtempC  maxtempF  mintempC  mintempF  avgtempC  \
# 3348       1 2017-08-31        24        76        13        56        19
# 3349       1 2017-09-01        22        72        12        54        18
# 3350       1 2017-09-02        26        79        16        61        21
# 3351       1 2017-09-03        29        85        16        60        23
# 3352       1 2017-09-04        23        73        15        59        19
# ...      ...        ...       ...       ...       ...       ...       ...
# 4652       1 2021-03-27        11        52         6        42         8
# 4653       1 2021-03-28         7        45         2        36         4
# 4654       1 2021-03-29        19        66         4        39        11
# 4655       1 2021-03-30        11        52         2        36         5
# 4656       1 2021-03-31         1        33        -3        26        -1
#
#       avgtempF  totalprecipMM  totalprecipIn  ...  WindGustKmph  FeelsLikeC  \
# 3348        66            0.0           0.00  ...            14          19
# 3349        64            0.2           0.01  ...            20          17
# 3350        69            3.6           0.14  ...            21          21
# 3351        73            0.0           0.00  ...            21          23
# 3352        66            0.4           0.02  ...            23          19
# ...        ...            ...            ...  ...           ...         ...
# 4652        47            5.9           0.23  ...            15           6
# 4653        39            4.7           0.19  ...            32          -1
# 4654        51            0.0           0.00  ...            34           9
# 4655        40            0.7           0.03  ...            30           0
# 4656        30            0.0           0.00  ...            24          -6
#
#       FeelsLikeF  uvIndex   sunrise    sunset  moonrise   moonset  \
# 3348          65        5  06:34 AM  07:52 PM  04:23 PM  01:08 AM
# 3349          63        5  06:35 AM  07:50 PM  05:10 PM  01:55 AM
# 3350          69        6  06:36 AM  07:48 PM  05:53 PM  02:47 AM
# 3351          74        6  06:38 AM  07:46 PM  06:31 PM  03:44 AM
# 3352          66        5  06:39 AM  07:44 PM  07:07 PM  04:44 AM
# ...          ...      ...       ...       ...       ...       ...
# 4652          43        2  07:02 AM  07:35 PM  06:21 PM  06:56 AM
# 4653          31        2  07:01 AM  07:37 PM  07:41 PM  07:22 AM
# 4654          47        4  06:59 AM  07:38 PM  09:01 PM  07:47 AM
# 4655          32        2  06:57 AM  07:39 PM  10:22 PM  08:12 AM
# 4656          21        2  06:55 AM  07:40 PM  11:44 PM  08:42 AM
#
#           moon_phase  moon_illumination
# 3348   First Quarter               41.4
# 3349  Waxing Gibbous               55.2
# 3350  Waxing Gibbous               62.1
# 3351  Waxing Gibbous               69.0
# 3352       Full Moon               75.9
# ...              ...                ...
# 4652  Waning Gibbous               96.6
# 4653  Waning Gibbous               89.7
# 4654  Waning Gibbous               82.8
# 4655  Waning Gibbous               75.9
# 4656    Last Quarter               69.0
#
# [1309 rows x 41 columns]

# %%
weather_df.head()
# Out:
#    loc_id       date  maxtempC  maxtempF  mintempC  mintempF  avgtempC  \
# 0       1 2008-07-01        29        83        16        61        23
# 1       1 2008-07-02        25        76        18        65        22
# 2       1 2008-07-03        25        77        13        55        19
# 3       1 2008-07-04        27        80        15        60        21
# 4       1 2008-07-05        28        82        18        64        22
#
#    avgtempF  totalprecipMM  totalprecipIn  ...  WindGustKmph  FeelsLikeC  \
# 0        73            0.0           0.00  ...            21          23
# 1        72            1.2           0.05  ...            24          23
# 2        65            0.0           0.00  ...             9          18
# 3        70            0.0           0.00  ...            11          21
# 4        72            0.0           0.00  ...            25          23
#
#    FeelsLikeF  uvIndex   sunrise    sunset  moonrise   moonset  \
# 0          74        6  05:31 AM  09:03 PM  03:25 AM  08:17 PM
# 1          74        6  05:31 AM  09:03 PM  04:31 AM  09:15 PM
# 2          65        5  05:32 AM  09:03 PM  05:49 AM  09:58 PM
# 3          70        6  05:33 AM  09:03 PM  07:12 AM  10:30 PM
# 4          74        6  05:33 AM  09:02 PM  08:33 AM  10:56 PM
#
#        moon_phase  moon_illumination
# 0  Waning Gibbous               89.7
# 1  Waning Gibbous               82.8
# 2  Waning Gibbous               75.9
# 3    Last Quarter               69.0
# 4    Last Quarter               62.1
#
# [5 rows x 41 columns]

# %%
weather_df.dtypes
# Out:
# loc_id                        int64
# date                 datetime64[ns]
# maxtempC                      int64
# maxtempF                      int64
# mintempC                      int64
# mintempF                      int64
# avgtempC                      int64
# avgtempF                      int64
# totalprecipMM               float64
# totalprecipIn               float64
# windspeedMiles                int64
# windspeedKmph                 int64
# sunhour                     float64
# winddirdegree                 int64
# winddir16point               object
# weatherCode                   int64
# weatherIconUrl               object
# weatherDesc                  object
# humidity                      int64
# visibilityKm                  int64
# visibilityMiles               int64
# pressureMB                    int64
# pressureInches                int64
# cloudcover                    int64
# HeatIndexC                    int64
# HeatIndexF                    int64
# DewPointC                     int64
# DewPointF                     int64
# WindChillC                    int64
# WindChillF                    int64
# WindGustMiles                 int64
# WindGustKmph                  int64
# FeelsLikeC                    int64
# FeelsLikeF                    int64
# uvIndex                       int64
# sunrise                      object
# sunset                       object
# moonrise                     object
# moonset                      object
# moon_phase                   object
# moon_illumination           float64
# dtype: object

# %%
# Simplify the weather dataframe
weather_data = weather_df[['date','weatherDesc', 'maxtempF', 'mintempF', 'avgtempF', 'totalprecipIn', 'windspeedMiles', 'humidity', 'FeelsLikeF','visibilityMiles']]
weather_data.head(50)
# Out:
#          date                  weatherDesc  maxtempF  mintempF  avgtempF  \
# 0  2008-07-01                Partly cloudy        83        61        73
# 1  2008-07-02                        Sunny        76        65        72
# 2  2008-07-03                        Sunny        77        55        65
# 3  2008-07-04                        Sunny        80        60        70
# 4  2008-07-05                        Sunny        82        64        72
# 5  2008-07-06                        Sunny        91        66        78
# 6  2008-07-07                        Sunny        80        67        74
# 7  2008-07-08                        Sunny        78        67        72
# 8  2008-07-09                        Sunny        82        59        71
# 9  2008-07-10                        Sunny        87        65        75
# 10 2008-07-11                        Sunny        90        68        79
# 11 2008-07-12                        Sunny        76        60        69
# 12 2008-07-13                        Sunny        78        62        70
# 13 2008-07-14                        Sunny        86        58        72
# 14 2008-07-15                        Sunny        92        71        80
# 15 2008-07-16                        Sunny        88        69        78
# 16 2008-07-17                        Sunny        84        69        75
# 17 2008-07-18                Partly cloudy        84        62        73
# 18 2008-07-19                        Sunny        75        61        67
# 19 2008-07-20                        Sunny        85        58        71
# 20 2008-07-21                        Sunny        82        64        72
# 21 2008-07-22                        Sunny        80        59        70
# 22 2008-07-23                        Sunny        81        60        71
# 23 2008-07-24                Partly cloudy        83        64        72
# 24 2008-07-25                        Sunny        86        67        76
# 25 2008-07-26                        Sunny        84        62        73
# 26 2008-07-27  Thundery outbreaks possible        84        64        73
# 27 2008-07-28                        Sunny        88        66        77
# 28 2008-07-29                        Sunny        90        74        81
# 29 2008-07-30                        Sunny        89        66        78
# 30 2008-07-31                        Sunny        87        66        75
# 31 2008-08-01                        Sunny        87        66        76
# 32 2008-08-02                        Sunny        84        59        72
# 33 2008-08-03                Partly cloudy        79        64        70
# 34 2008-08-04                        Sunny        90        66        76
# 35 2008-08-05                        Sunny        85        64        75
# 36 2008-08-06                        Sunny        83        63        73
# 37 2008-08-07                        Sunny        80        60        70
# 38 2008-08-08                        Sunny        81        52        68
# 39 2008-08-09                        Sunny        84        63        73
# 40 2008-08-10                        Sunny        80        53        67
# 41 2008-08-11                        Sunny        80        56        68
# 42 2008-08-12                Partly cloudy        74        59        64
# 43 2008-08-13                Partly cloudy        83        60        70
# 44 2008-08-14                        Sunny        80        60        69
# 45 2008-08-15                        Sunny        82        58        70
# 46 2008-08-16                        Sunny        84        60        72
# 47 2008-08-17                        Sunny        86        65        75
# 48 2008-08-18                        Sunny        91        64        77
# 49 2008-08-19                        Sunny        88        64        76
#
#     totalprecipIn  windspeedMiles  humidity  FeelsLikeF  visibilityMiles
# 0            0.00               8        62          74                6
# 1            0.05              10        62          74                6
# 2            0.00               4        67          65                6
# 3            0.00               4        66          70                6
# 4            0.00              10        65          74                6
# 5            0.17               6        71          82                6
# 6            0.25               5        81          77                5
# 7            0.01               9        67          73                4
# 8            0.00               5        60          71                6
# 9            0.05               8        62          78                6
# 10           0.18              12        76          83                5
# 11           0.00              12        48          69                6
# 12           0.00              13        49          70                6
# 13           0.00               5        58          73                6
# 14           0.00               5        63          84                6
# 15           0.02               7        67          82                6
# 16           0.11               8        85          79                6
# 17           0.01               5        75          74                4
# 18           0.14               5        84          67                4
# 19           0.00               4        78          71                3
# 20           0.00               5        69          73                6
# 21           0.00               6        74          70                4
# 22           0.00               5        64          71                6
# 23           0.00               7        68          74                6
# 24           0.02               8        67          78                6
# 25           0.00               6        51          74                6
# 26           0.05               4        72          77                5
# 27           0.00               6        72          79                6
# 28           0.01               9        60          83                6
# 29           0.00               6        55          79                6
# 30           0.00               3        63          77                6
# 31           0.00               8        58          76                6
# 32           0.00               5        59          73                6
# 33           0.02               9        71          70                6
# 34           0.01               5        78          79                4
# 35           0.00               7        55          77                6
# 36           0.00               6        54          74                6
# 37           0.00               5        61          70                6
# 38           0.05               3        65          68                6
# 39           0.13               5        67          73                5
# 40           0.00               5        54          66                6
# 41           0.00               6        60          67                6
# 42           0.52               6        89          64                5
# 43           0.00               3        73          70                4
# 44           0.03               5        70          69                6
# 45           0.00               3        72          70                6
# 46           0.00               7        60          74                6
# 47           0.00               8        56          76                6
# 48           0.00               6        55          78                6
# 49           0.00               6        64          77                6

# %%
weather_data.groupby(['weatherDesc', 'date']).sum()
# Out:
#                                         maxtempF  mintempF  avgtempF  \
# weatherDesc                 date
# Blizzard                    2009-01-23        20         0        12
#                             2009-02-18        32         9        22
#                             2009-12-09        17         3        10
#                             2010-12-11        19         6        15
#                             2011-02-20        26        20        23
# ...                                          ...       ...       ...
# Thundery outbreaks possible 2019-06-14        78        59        67
#                             2020-08-08        82        74        78
#                             2020-08-09        86        76        81
#                             2020-08-13        80        66        73
# Torrential rain shower      2016-05-23        78        63        69
#
#                                         totalprecipIn  windspeedMiles  \
# weatherDesc                 date
# Blizzard                    2009-01-23           0.01              15
#                             2009-02-18           0.11              13
#                             2009-12-09           0.27              18
#                             2010-12-11           1.00              16
#                             2011-02-20           0.61              12
# ...                                               ...             ...
# Thundery outbreaks possible 2019-06-14           0.49              12
#                             2020-08-08           0.06               9
#                             2020-08-09           0.01               7
#                             2020-08-13           0.05              11
# Torrential rain shower      2016-05-23           0.80              13
#
#                                         humidity  FeelsLikeF  visibilityMiles
# weatherDesc                 date
# Blizzard                    2009-01-23        96          -4                4
#                             2009-02-18        90           9                1
#                             2009-12-09        96          -9                0
#                             2010-12-11        99          -2                0
#                             2011-02-20        98          12                1
# ...                                          ...         ...              ...
# Thundery outbreaks possible 2019-06-14        72          67                5
#                             2020-08-08        80          82                5
#                             2020-08-09        79          88                5
#                             2020-08-13        79          76                5
# Torrential rain shower      2016-05-23        77          69                4
#
# [4687 rows x 8 columns]

# %%
Blizzard_df = weather_data.loc[(weather_data['weatherDesc'] == 'Blizzard') | (weather_data['weatherDesc'] == 'Blowing snow')]
Flood_df = weather_data[(weather_data['weatherDesc'] == 'Light rain')]
IceStorm_df = weather_data[(weather_data['weatherDesc'] == 'Heavy snow')]

# %%
Blizzard_Weather = Blizzard_df.groupby(['weatherDesc', 'date']).sum()
Flood_Weather = Flood_df.groupby(['weatherDesc', 'date']).sum()
IceStorm_Weather = IceStorm_df.groupby(['weatherDesc', 'date']).sum()

# %%
Blizzard_Weather
# Out:
#                          maxtempF  mintempF  avgtempF  totalprecipIn  \
# weatherDesc  date
# Blizzard     2009-01-23        20         0        12           0.01
#              2009-02-18        32         9        22           0.11
#              2009-12-09        17         3        10           0.27
#              2010-12-11        19         6        15           1.00
#              2011-02-20        26        20        23           0.61
#              2011-03-12        31        17        23           0.04
#              2011-04-04        42        32        36           0.06
#              2012-12-20        25        16        21           0.14
#              2013-02-11        26        19        24           0.08
#              2013-04-19        34        28        31           0.08
#              2014-01-16        31         4        18           0.03
#              2014-01-22         7        -7         0           0.02
#              2014-03-21        35        21        30           0.08
#              2015-02-01        19        10        14           0.13
#              2015-11-26        38        26        32           0.17
#              2016-02-02        31        22        27           0.37
#              2016-02-03        24        14        18           0.05
#              2017-02-24        29        23        27           0.13
#              2017-10-27        37        32        34           0.22
#              2018-01-22        32        26        30           0.87
#              2018-04-14        30        23        27           1.34
#              2018-12-02        33        27        31           0.06
#              2019-01-24        16        -6         5           0.02
#              2019-02-24        29        -2        14           0.15
#              2019-04-11        34        29        32           0.66
#              2019-11-27        31        23        27           0.43
# Blowing snow 2013-12-17        26        15        21           0.00
#              2015-02-11        28         7        18           0.02
#              2015-12-17        28        18        25           0.00
#              2016-01-15        24         7        18           0.04
#              2016-02-09        14         5         9           0.01
#              2016-03-23        37        32        34           0.20
#              2016-04-01        42        31        36           0.02
#              2016-04-08        34        21        30           0.02
#              2016-11-19        29        20        26           0.02
#              2016-12-07        21        15        18           0.00
#              2017-01-03        30         4        17           0.00
#
#                          windspeedMiles  humidity  FeelsLikeF  visibilityMiles
# weatherDesc  date
# Blizzard     2009-01-23              15        96          -4                4
#              2009-02-18              13        90           9                1
#              2009-12-09              18        96          -9                0
#              2010-12-11              16        99          -2                0
#              2011-02-20              12        98          12                1
#              2011-03-12              13        98          10                2
#              2011-04-04              14        89          28                3
#              2012-12-20              13        90           8                2
#              2013-02-11              14        87          11                2
#              2013-04-19              13        92          20                3
#              2014-01-16              14        87           3                3
#              2014-01-22              12        90         -17                2
#              2014-03-21              10        94          20                4
#              2015-02-01              16        78          -3                2
#              2015-11-26              13        84          22                3
#              2016-02-02              16        93          15                3
#              2016-02-03              15        90           4                3
#              2017-02-24              16        67          14                0
#              2017-10-27              17        84          24                2
#              2018-01-22              15        92          19                1
#              2018-04-14              18        90          14                1
#              2018-12-02              15        83          20                2
#              2019-01-24              13        82         -12                3
#              2019-02-24              15        85          -4                1
#              2019-04-11              20        91          20                1
#              2019-11-27              12        92          16                2
# Blowing snow 2013-12-17              13        84           9                4
#              2015-02-11              19        81           1                2
#              2015-12-17              17        70          11                2
#              2016-01-15              13        92           3                2
#              2016-02-09              14        86          -9                3
#              2016-03-23              16        77          24                2
#              2016-04-01              14        60          27                4
#              2016-04-08              17        60          18                2
#              2016-11-19              14        87          14                2
#              2016-12-07              19        72           2                3
#              2017-01-03              14        91           3                2

# %%
BlizzData = Blizzard_df.groupby(pd.Grouper(key="date", freq="1M")).sum()
BlizzData
# Out:
#             maxtempF  mintempF  avgtempF  totalprecipIn  windspeedMiles  \
# date
# 2009-01-31        20         0        12           0.01              15
# 2009-02-28        32         9        22           0.11              13
# 2009-03-31         0         0         0           0.00               0
# 2009-04-30         0         0         0           0.00               0
# 2009-05-31         0         0         0           0.00               0
# ...              ...       ...       ...            ...             ...
# 2019-07-31         0         0         0           0.00               0
# 2019-08-31         0         0         0           0.00               0
# 2019-09-30         0         0         0           0.00               0
# 2019-10-31         0         0         0           0.00               0
# 2019-11-30        31        23        27           0.43              12
#
#             humidity  FeelsLikeF  visibilityMiles
# date
# 2009-01-31        96          -4                4
# 2009-02-28        90           9                1
# 2009-03-31         0           0                0
# 2009-04-30         0           0                0
# 2009-05-31         0           0                0
# ...              ...         ...              ...
# 2019-07-31         0           0                0
# 2019-08-31         0           0                0
# 2019-09-30         0           0                0
# 2019-10-31         0           0                0
# 2019-11-30        92          16                2
#
# [131 rows x 8 columns]

# %%
x_values = Blizzard_df['date']
y_values = Blizzard_df['FeelsLikeF']
# plt.scatter(x_values, BlizzData, marker="o", facecolors="red", edgecolors="black",
#             s=x_values, alpha=0.75, label='Temperature (F)')

plt.figure(figsize=(16, 8))
plt.scatter(x_values, y_values, marker="o", facecolors="red", edgecolors="black")
plt.grid()
plt.xlabel('Date ')
plt.ylabel('FeelsLikeF')
plt.title('FeelsLikeF Temp in Different Blizzard Weather Event through 2017-2021')
plt.legend()
plt.savefig('FeelsLikeFBlizzard Weather Event 2017-2021')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cfcee7262808> in <module>
# ----> 1 x_values = Blizzard_df['date']
#       2 y_values = Blizzard_df['FeelsLikeF']
#       3 # plt.scatter(x_values, BlizzData, marker="o", facecolors="red", edgecolors="black",
#       4 #             s=x_values, alpha=0.75, label='Temperature (F)')
#       5
#
# NameError: name 'Blizzard_df' is not defined

# %%
Flood_Weather
# Out:
#                         maxtempF  mintempF  avgtempF  totalprecipIn  \
# weatherDesc date
# Light rain  2009-04-19        51        39        44           0.20
#             2010-05-11        42        36        39           0.37
#             2011-04-26        48        37        43           1.14
#             2011-06-22        67        54        63           0.38
#             2012-03-22        65        56        60           0.57
#             2012-10-22        56        49        53           0.11
#             2013-03-30        39        36        38           0.18
#             2013-05-01        53        36        42           0.36
#             2014-03-11        35        27        33           0.25
#             2015-04-06        41        36        39           0.26
#             2015-05-14        55        50        53           0.35
#             2015-05-26        64        54        59           0.16
#             2015-06-11        64        57        60           0.32
#             2015-06-13        69        60        63           0.11
#             2015-09-24        66        63        64           0.45
#             2016-03-15        58        47        52           0.28
#             2016-09-07        75        62        69           0.21
#             2017-08-26        66        59        63           0.33
#             2017-09-18        60        58        58           0.32
#             2017-10-07        68        54        58           0.23
#             2019-05-08        52        40        44           0.91
#             2019-10-10        60        51        57           0.25
#             2019-10-21        56        47        51           0.69
#             2019-11-17        36        32        34           0.09
#             2020-04-24        43        29        40           0.15
#             2021-03-10        51        36        42           0.33
#             2021-04-12        50        39        45           0.27
#             2021-04-29        47        33        43           0.10
#
#                         windspeedMiles  humidity  FeelsLikeF  visibilityMiles
# weatherDesc date
# Light rain  2009-04-19               7        80          39                5
#             2010-05-11               8        98          32                4
#             2011-04-26              12        97          36                4
#             2011-06-22               8        95          62                5
#             2012-03-22               7        95          59                4
#             2012-10-22               9        92          50                4
#             2013-03-30               8       100          31                4
#             2013-05-01               7        84          37                5
#             2014-03-11               9        98          25                4
#             2015-04-06              15        84          30                3
#             2015-05-14              14        83          48                5
#             2015-05-26               5        89          58                5
#             2015-06-11               9        81          60                5
#             2015-06-13               7        85          63                6
#             2015-09-24               6        92          64                4
#             2016-03-15              10        86          48                5
#             2016-09-07               5        90          69                5
#             2017-08-26              10        87          62                5
#             2017-09-18               7        71          58                5
#             2017-10-07               7        82          57                4
#             2019-05-08              14        77          37                5
#             2019-10-10              10        83          55                4
#             2019-10-21              12        80          47                4
#             2019-11-17               9        84          28                5
#             2020-04-24               5        85          37                5
#             2021-03-10               8        86          37                5
#             2021-04-12              10        83          40                5
#             2021-04-29              12        76          39                6

# %%
x_values = Flood_df['date']
y_values = Flood_df['FeelsLikeF']
# plt.scatter(x_values, BlizzData, marker="o", facecolors="red", edgecolors="black",
#             s=x_values, alpha=0.75, label='Temperature (F)')

plt.figure(figsize=(16, 8))
plt.scatter(x_values, y_values, marker="o", facecolors="red", edgecolors="black")
plt.grid()
plt.xlabel('Date')
plt.ylabel('FeelsLikeF')
plt.title('FeelsLikeF Temp in Different Flood Weather Event through 2017-2021')
plt.legend()
plt.savefig('FeelsLikeFFlood Weather Event 2017-2021')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
IceStorm_Weather
# Out:
#                         maxtempF  mintempF  avgtempF  totalprecipIn  \
# weatherDesc date
# Heavy snow  2008-11-07        43        35        38           0.22
#             2008-12-09        21        10        16           0.09
#             2008-12-16         7        -5         1           0.07
#             2008-12-19        22        13        17           0.15
#             2008-12-20        22         0        15           0.19
# ...                          ...       ...       ...            ...
#             2021-02-04        34         5        21           0.21
#             2021-02-21        30        18        25           0.04
#             2021-02-28        32         6        22           0.27
#             2021-03-01        18        12        15           0.02
#             2021-03-15        35        29        31           0.28
#
#                         windspeedMiles  humidity  FeelsLikeF  visibilityMiles
# weatherDesc date
# Heavy snow  2008-11-07               4        94          35                2
#             2008-12-09              10        95           3                3
#             2008-12-16               6        95         -12                3
#             2008-12-19               7        97           8                2
#             2008-12-20              11        98           1                2
# ...                                ...       ...         ...              ...
#             2021-02-04              14        94           8                2
#             2021-02-21               6        96          19                1
#             2021-02-28              10        88          13                4
#             2021-03-01               6        88           6                5
#             2021-03-15              12        73          22                2
#
# [111 rows x 8 columns]

# %%
x_values = IceStorm_df['date']
y_values = IceStorm_df['FeelsLikeF']
# plt.scatter(x_values, BlizzData, marker="o", facecolors="red", edgecolors="black",
#             s=x_values, alpha=0.75, label='Temperature (F)')

plt.figure(figsize=(16, 8))
plt.scatter(x_values, y_values, marker="o", facecolors="red", edgecolors="black")
plt.grid()
plt.xlabel('Date')
plt.ylabel('FeelsLikeF')
plt.title('FeelsLikeF Temp in Different IceStorm Weather Event through 2017-2021')
plt.legend()
plt.savefig('FeelsLikeFIceStorm Weather Event 2017-2021')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#=======================CRIMES PER WEATHER EVENTS===================

# %%
# Read in the crime data

Crime_df = pd.read_csv("../Resources/NEIGHBORHOOD_CRIME_STATS.csv")
Crime_df.head()
# Out:
#    neighborhoodCrimeStatisticsID        neighborhood      ucrDescription  \
# 0                              1  ** NOT ASSIGNED **  Aggravated Assault
# 1                              2  ** NOT ASSIGNED **               Arson
# 2                              3  ** NOT ASSIGNED **          Auto Theft
# 3                              4  ** NOT ASSIGNED **            Burglary
# 4                              5  ** NOT ASSIGNED **            Homicide
#
#    number  reportMonth  reportYear
# 0     2.0            8        2017
# 1     0.0            8        2017
# 2     3.0            8        2017
# 3     1.0            8        2017
# 4     0.0            8        2017

# %%
Crime_df.dtypes
# Out:
# neighborhoodCrimeStatisticsID      int64
# neighborhood                      object
# ucrDescription                    object
# number                           float64
# reportMonth                        int64
# reportYear                         int64
# dtype: object

# %%
AllCrime_df= Crime_df.groupby(['ucrDescription', 'reportYear']).sum()
AllCrime_df
# Out:
#                                neighborhoodCrimeStatisticsID   number  \
# ucrDescription     reportYear
# Aggravated Assault 2017                               773080    887.0
#                    2018                              8174496   1797.0
#                    2019                             17095584   1963.0
#                    2020                             26016672   2357.0
#                    2021                              7898088    411.0
# Arson              2017                               773520     52.0
#                    2018                              8175552     71.0
#                    2019                             17096640     70.0
#                    2020                             26017728    113.0
#                    2021                              7898352     18.0
# Auto Theft         2017                               773960    982.0
#                    2018                              8176608   2219.0
#                    2019                             17097696   2878.0
#                    2020                             26018784   3930.0
#                    2021                              7898616   1007.0
# Burglary           2017                               774400   1715.0
#                    2018                              8177664   3059.0
#                    2019                             17098752   3329.0
#                    2020                             26019840   3932.0
#                    2021                              7898880    514.0
# Homicide           2017                               774840     16.0
#                    2018                              8178720     30.0
#                    2019                             17099808     43.0
#                    2020                             26020896     74.0
#                    2021                              7899144     16.0
# Larceny            2017                               775280   5558.0
#                    2018                              8179776  11513.0
#                    2019                             17100864  13037.0
#                    2020                             26021952  11697.0
#                    2021                              7899408   2115.0
# Rape               2017                               775720    206.0
#                    2018                              8180832    455.0
#                    2019                             17101920    474.0
#                    2020                             26023008    385.0
#                    2021                              7899672    103.0
# Robbery            2017                               776160    724.0
#                    2018                              8181888   1188.0
#                    2019                             17102976   1305.0
#                    2020                             26024064   1732.0
#                    2021                              7899936    363.0
#
#                                reportMonth
# ucrDescription     reportYear
# Aggravated Assault 2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Arson              2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Auto Theft         2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Burglary           2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Homicide           2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Larceny            2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Rape               2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528
# Robbery            2017               4400
#                    2018               6864
#                    2019               6864
#                    2020               6864
#                    2021                528

# %%
Crime_df['ucrDescription'].unique()
# Out:
# array(['Aggravated Assault', 'Arson', 'Auto Theft', 'Burglary',
#        'Homicide', 'Larceny', 'Rape', 'Robbery'], dtype=object)

# %%
Crime_df['Date'] = pd.to_datetime(Crime_df.reportYear.astype(str) + '/' + Crime_df.reportMonth.astype(str) + '/01')
Crime_df.drop(labels=['reportMonth', 'reportYear'], axis=1, inplace=True)
Crime_df = Crime_df.dropna()
Crime_df = Crime_df[Crime_df['number'] != 0]
Crime_df.to_csv("../Resources/crime_date.csv", encoding="utf-8", index=False)
Crime_df = pd.read_csv('../Resources/crime_date.csv')
Crime_df
# Out:
#        neighborhoodCrimeStatisticsID          neighborhood  \
# 0                                  1    ** NOT ASSIGNED **
# 1                                  3    ** NOT ASSIGNED **
# 2                                  4    ** NOT ASSIGNED **
# 3                                  6    ** NOT ASSIGNED **
# 4                                  7    ** NOT ASSIGNED **
# ...                              ...                   ...
# 15342                          30968           Windom Park
# 15343                          30969  Z_** NOT ASSIGNED **
# 15344                          30971  Z_** NOT ASSIGNED **
# 15345                          30974  Z_** NOT ASSIGNED **
# 15346                          30975  Z_** NOT ASSIGNED **
#
#            ucrDescription  number        Date
# 0      Aggravated Assault     2.0  2017-08-01
# 1              Auto Theft     3.0  2017-08-01
# 2                Burglary     1.0  2017-08-01
# 3                 Larceny     8.0  2017-08-01
# 4                    Rape     2.0  2017-08-01
# ...                   ...     ...         ...
# 15342             Robbery     1.0  2021-03-01
# 15343  Aggravated Assault     2.0  2021-03-01
# 15344          Auto Theft     2.0  2021-03-01
# 15345             Larceny     8.0  2021-03-01
# 15346                Rape     3.0  2021-03-01
#
# [15347 rows x 5 columns]

# %%
# Non-violent crime (Arson,Auto theft,Burglary and Larceny)

# %%
Crime_df['Date'] = pd.to_datetime(Crime_df['Date'])
Arson_df = Crime_df[(Crime_df['ucrDescription'] == 'Arson')]
AutoTheft_df = Crime_df[(Crime_df['ucrDescription'] == 'Auto Theft')]
Burglary_df = Crime_df[(Crime_df['ucrDescription'] == 'Burglary')]
Larceny_df = Crime_df[(Crime_df['ucrDescription'] == 'Larceny')]

# %%
Arson_month = Arson_df.groupby(pd.Grouper(key="Date", freq="1M")).sum()
AutoTheft_month = AutoTheft_df.groupby(pd.Grouper(key="Date", freq="1M")).sum()
Burglary_month = Arson_df.groupby(pd.Grouper(key="Date", freq="1M")).sum()
Larceny_month = Arson_df.groupby(pd.Grouper(key="Date", freq="1M")).sum()

# %%
Arson_month
# Out:
#             neighborhoodCrimeStatisticsID  number
# Date
# 2017-08-31                           2358     9.0
# 2017-09-30                          11268    18.0
# 2017-10-31                          10892     6.0
# 2017-11-30                          15212    10.0
# 2017-12-31                          22758     9.0
# 2018-01-31                          15616     4.0
# 2018-02-28                          14230     3.0
# 2018-03-31                          37414     9.0
# 2018-04-30                          12020     2.0
# 2018-05-31                          46998     7.0
# 2018-06-30                          75180    11.0
# 2018-07-31                          80500    12.0
# 2018-08-31                          34712     4.0
# 2018-09-30                          47178     5.0
# 2018-10-31                          71878     8.0
# 2018-11-30                          11146     1.0
# 2018-12-31                          35006     5.0
# 2019-01-31                          24380     2.0
# 2019-02-28                          52912     4.0
# 2019-03-31                          13730     1.0
# 2019-04-30                          57624     4.0
# 2019-05-31                         106798     7.0
# 2019-06-30                         207082    15.0
# 2019-07-31                         115614     7.0
# 2019-08-31                         103548     7.0
# 2019-09-30                         179748    11.0
# 2019-10-31                          74560     4.0
# 2019-11-30                          76904     4.0
# 2019-12-31                          60246     4.0
# 2020-01-31                          82912     4.0
# 2020-02-29                         107426     5.0
# 2020-03-31                         110946     5.0
# 2020-04-30                          68854     3.0
# 2020-05-31                         118234     6.0
# 2020-06-30                         340628    19.0
# 2020-07-31                         475494    21.0
# 2020-08-31                         257020    14.0
# 2020-09-30                         290614    14.0
# 2020-10-31                         270644    13.0
# 2020-11-30                         138602     6.0
# 2020-12-31                          85550     3.0
# 2021-01-31                         205350     8.0
# 2021-02-28                          89686     4.0
# 2021-03-31                         153282     6.0

# %%
AutoTheft_month
# Out:
#             neighborhoodCrimeStatisticsID  number
# Date
# 2017-08-31                          23043   207.0
# 2017-09-30                          70582   193.0
# 2017-10-31                         118225   176.0
# 2017-11-30                         150935   186.0
# 2017-12-31                         186841   220.0
# 2018-01-31                         287110   278.0
# 2018-02-28                         240020   198.0
# 2018-03-31                         275548   170.0
# 2018-04-30                         311004   134.0
# 2018-05-31                         395633   167.0
# 2018-06-30                         369134   141.0
# 2018-07-31                         510797   170.0
# 2018-08-31                         536583   168.0
# 2018-09-30                         609952   154.0
# 2018-10-31                         705255   201.0
# 2018-11-30                         699344   218.0
# 2018-12-31                         755971   220.0
# 2019-01-31                         750815   221.0
# 2019-02-28                         858750   201.0
# 2019-03-31                         906822   213.0
# 2019-04-30                         965953   187.0
# 2019-05-31                         982827   232.0
# 2019-06-30                         998413   229.0
# 2019-07-31                        1143023   250.0
# 2019-08-31                        1173108   297.0
# 2019-09-30                        1219764   296.0
# 2019-10-31                        1286727   227.0
# 2019-11-30                        1220789   258.0
# 2019-12-31                        1224271   267.0
# 2020-01-31                        1579332   406.0
# 2020-02-29                        1460548   355.0
# 2020-03-31                        1552946   293.0
# 2020-04-30                        1509590   248.0
# 2020-05-31                        1628839   237.0
# 2020-06-30                        1846652   329.0
# 2020-07-31                        1924087   391.0
# 2020-08-31                        1903030   384.0
# 2020-09-30                        1979713   310.0
# 2020-10-31                        2032993   322.0
# 2020-11-30                        1892684   326.0
# 2020-12-31                        2110078   329.0
# 2021-01-31                        2219396   371.0
# 2021-02-28                        2333634   390.0
# 2021-03-31                        2083388   246.0

# %%
Burglary_month
# Out:
#             neighborhoodCrimeStatisticsID  number
# Date
# 2017-08-31                           2358     9.0
# 2017-09-30                          11268    18.0
# 2017-10-31                          10892     6.0
# 2017-11-30                          15212    10.0
# 2017-12-31                          22758     9.0
# 2018-01-31                          15616     4.0
# 2018-02-28                          14230     3.0
# 2018-03-31                          37414     9.0
# 2018-04-30                          12020     2.0
# 2018-05-31                          46998     7.0
# 2018-06-30                          75180    11.0
# 2018-07-31                          80500    12.0
# 2018-08-31                          34712     4.0
# 2018-09-30                          47178     5.0
# 2018-10-31                          71878     8.0
# 2018-11-30                          11146     1.0
# 2018-12-31                          35006     5.0
# 2019-01-31                          24380     2.0
# 2019-02-28                          52912     4.0
# 2019-03-31                          13730     1.0
# 2019-04-30                          57624     4.0
# 2019-05-31                         106798     7.0
# 2019-06-30                         207082    15.0
# 2019-07-31                         115614     7.0
# 2019-08-31                         103548     7.0
# 2019-09-30                         179748    11.0
# 2019-10-31                          74560     4.0
# 2019-11-30                          76904     4.0
# 2019-12-31                          60246     4.0
# 2020-01-31                          82912     4.0
# 2020-02-29                         107426     5.0
# 2020-03-31                         110946     5.0
# 2020-04-30                          68854     3.0
# 2020-05-31                         118234     6.0
# 2020-06-30                         340628    19.0
# 2020-07-31                         475494    21.0
# 2020-08-31                         257020    14.0
# 2020-09-30                         290614    14.0
# 2020-10-31                         270644    13.0
# 2020-11-30                         138602     6.0
# 2020-12-31                          85550     3.0
# 2021-01-31                         205350     8.0
# 2021-02-28                          89686     4.0
# 2021-03-31                         153282     6.0

# %%
Larceny_month
# Out:
#             neighborhoodCrimeStatisticsID  number
# Date
# 2017-08-31                           2358     9.0
# 2017-09-30                          11268    18.0
# 2017-10-31                          10892     6.0
# 2017-11-30                          15212    10.0
# 2017-12-31                          22758     9.0
# 2018-01-31                          15616     4.0
# 2018-02-28                          14230     3.0
# 2018-03-31                          37414     9.0
# 2018-04-30                          12020     2.0
# 2018-05-31                          46998     7.0
# 2018-06-30                          75180    11.0
# 2018-07-31                          80500    12.0
# 2018-08-31                          34712     4.0
# 2018-09-30                          47178     5.0
# 2018-10-31                          71878     8.0
# 2018-11-30                          11146     1.0
# 2018-12-31                          35006     5.0
# 2019-01-31                          24380     2.0
# 2019-02-28                          52912     4.0
# 2019-03-31                          13730     1.0
# 2019-04-30                          57624     4.0
# 2019-05-31                         106798     7.0
# 2019-06-30                         207082    15.0
# 2019-07-31                         115614     7.0
# 2019-08-31                         103548     7.0
# 2019-09-30                         179748    11.0
# 2019-10-31                          74560     4.0
# 2019-11-30                          76904     4.0
# 2019-12-31                          60246     4.0
# 2020-01-31                          82912     4.0
# 2020-02-29                         107426     5.0
# 2020-03-31                         110946     5.0
# 2020-04-30                          68854     3.0
# 2020-05-31                         118234     6.0
# 2020-06-30                         340628    19.0
# 2020-07-31                         475494    21.0
# 2020-08-31                         257020    14.0
# 2020-09-30                         290614    14.0
# 2020-10-31                         270644    13.0
# 2020-11-30                         138602     6.0
# 2020-12-31                          85550     3.0
# 2021-01-31                         205350     8.0
# 2021-02-28                          89686     4.0
# 2021-03-31                         153282     6.0

# %%
# Auto Theft and Larceny cases during BlizzerWeather2017-2021

x2_values =  AutoTheft_month['number']
x4_values =  Larceny_month['number']
y_values = Blizzard_df['date']
plt.figure(figsize=(15, 6))
plt.plot(x2_values, marker='o', label='Auto Theft')
plt.plot(x4_values, marker='v', label='Larceny')
plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Auto Theft and Larceny Cases')
plt.title('Auto Theft and Larceny cases during BlizzardWeather2017-2021')
plt.legend()
plt.savefig('AutoTheftLarcenyBlizzardWeather2017-2021')
plt.show()

# %%
# Perform a linear regression on Temperature vs. Assault
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(200,50),fontsize=15,color="red")
plt.xlabel('Assault')
plt.ylabel('Avg Temp (F)')
plt.title('Temperature (F) & Assault(2017-2021)')
#plt.savefig('line_reg for Temperature vs Assault')
print(f"The r-value is: {rvalue**2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-322-0e0c224c5961> in <module>
#       1 # Perform a linear regression on Temperature vs. Assault
# ----> 2 slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_values, y_values)
#       3
#       4 # Get regression values
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'stats' is not defined

# %%
x1_values =  Arson_month['number']

y_values = Blizzard_df['date']
plt.figure(figsize=(15, 6))
plt.plot(x1_values, marker='+', label='Arson', color='maroon')

plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Arsons Cases')
plt.title('Arson cases during BlizzardWeather2017-2021')
plt.legend()
plt.savefig('Arson cases during BlizzardWeather2017-2021')
plt.show()

# %%
x3_values =  Burglary_month['number']

y_values = Blizzard_df['date']
plt.figure(figsize=(15, 6))

plt.plot(x3_values, marker='o', label='Burglary', color='red')
plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Burglary Cases')
plt.title('Burglary cases during BlizzardWeather2017-2021')
plt.legend()
plt.savefig('Burglary cases during BlizzardWeather2017-2021')
plt.show()

# %%
# Auto Theft and Larceny cases during FloodWeather2017-2021

x2_values =  AutoTheft_month['number']
x4_values =  Larceny_month['number']
y_values = Flood_df['date']



plt.figure(figsize=(15, 6))
plt.plot(x2_values, marker='o', label='Auto Theft')
plt.plot(x4_values, marker='v', label='Larceny')

plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Auto Theft and Larceny Cases')
plt.title('Auto Theft and Larceny cases during FloodWeather2017-2021')
plt.legend()
plt.savefig('AutoTheftLarcenyFloodWeather2017-2021')
plt.show()

# %%
x1_values =  Arson_month['number']

y_values = Flood_df['date']
plt.figure(figsize=(15, 6))
plt.plot(x1_values, marker='+', label='Arson', color='maroon')

plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Arsons Cases')
plt.title('Arson cases during FloodWeather2017-2021')
plt.legend()
plt.savefig('Arson cases during FloodWeather2017-2021')
plt.show()

# %%
x3_values =  Burglary_month['number']

y_values = Flood_df['date']
plt.figure(figsize=(15, 6))

plt.plot(x3_values, marker='o', label='Burglary', color='red')
plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Burglary Cases')
plt.title('Burglary cases during FloodWeather2017-2021')
plt.legend()
plt.savefig('Burglary cases during FloodWeather2017-2021')
plt.show()

# %%
# Auto Theft and Larceny cases during IceStormWeather2017-2021

x2_values =  AutoTheft_month['number']
x4_values =  Larceny_month['number']
y_values = IceStorm_df['date']



plt.figure(figsize=(15, 6))
plt.plot(x2_values, marker='o', label='Auto Theft')
plt.plot(x4_values, marker='v', label='Larceny')

plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Auto Theft and Larceny Cases')
plt.title('Auto Theft and Larceny cases during IceStormWeather2017-2021')
plt.legend()
plt.savefig('AutoTheftLarcenyIceStormWeather2017-2021')
plt.show()

# %%
x1_values =  Arson_month['number']

y_values = IceStorm_df['date']
plt.figure(figsize=(15, 6))
plt.plot(x1_values, marker='+', label='Arson', color='maroon')

plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Arsons Cases')
plt.title('Arson cases during IceStormWeather2017-2021')
plt.legend()
plt.savefig('Arson cases during IceStormWeather2017-2021')
plt.show()

# %%
x3_values =  Burglary_month['number']

y_values = IceStorm_df['date']
plt.figure(figsize=(15, 6))

plt.plot(x3_values, marker='o', label='Burglary', color='red')
plt.grid()
plt.xlabel('Date (Year-Months(+6))')
plt.ylabel('Burglary Cases')
plt.title('Burglary cases during IceStormWeather2017-2021')
plt.legend()
plt.savefig('Burglary cases during IceStormWeather2017-2021')
plt.show()
